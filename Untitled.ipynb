# %%
tahun = "2021-Now"
judul1 ="Curriculum VITAE"
judul2 ="Pendidikan Formal"
judul2b ="Pendidikan Non-formal"
judul3 ="Prestasi"
judul4 ="Pengalaman Kerja"
judul5 ="Organisasi"
judul6 ="Kontak"
nama="Andreas Jefri"
gender="Laki-laki"
nationality="Indonesia"
alamat = """Komplek pondok indah lestari,kab.kubu raya"""
pendidikan_formal ="""
- SD 02 Nanga Arong
- SMP Harapan Ananda
- SMA Negeri 1 Sungai Raya"""
pendidikan_non_formal ="""
- Bela Negara
- Pelatihan Memasak"""
prestasi="""
- Juara 3 Lomba Masak Sekalbar
- Runer Up Duta Smansa
- Juara 1 Karate"""
pengalaman="""
- Bekerja sebagai Staf Lapangan PD.PENDI
"""
organisasi="""
- IPDK
- PEMUDA BORNEO
- PENCINTA ALAM KALBAR
- PANGALAYO
"""
kontak="""
- 085821136572 (WhatsApp)
- Andreas Jefri (Facebook)
- @Andreasvan17(Instagram)
- Andreasvan17@gmail.com (Email)"""
cvnama="PD.PENDI GROUP"

#cetak judul
print("=============================================================\n")
print ('{:>38}'.format(judul1))
print("\n=============================================================")

#cetak subjudul
print('{:>60}'.format(cvnama))
print('{:>60}'.format(tahun))

print("\nNama                  : ", nama)
print("Jenis Kelamin         : ", gender)
print("Kebangsaan            : ", nationality)
print("Alamat                : ", alamat)

print("\n\n")

#cetak judul
print("=============================================================\n")
print ('{:>36}'.format(judul2))
print("\n=============================================================")

print(pendidikan_formal)

#cetak judul
print("=============================================================\n")
print ('{:>36}'.format(judul2b))
print("\n=============================================================")

print(pendidikan_non_formal)

print("\n\n")

#cetak judul
print("=============================================================\n")
print ('{:>35}'.format(judul3))
print("\n=============================================================")

print(prestasi)

print("\n\n")

#cetak judul
print("=============================================================\n")
print ('{:>38}'.format(judul4))
print("\n=============================================================")

print(pengalaman)

print("\n\n")

#cetak judul
print("=============================================================\n")
print ('{:>36}'.format(judul5))
print("\n=============================================================")

print(organisasi)

print("\n\n")

#cetak judul
print("=============================================================\n")
print ('{:>34}'.format(judul6))
print("\n=============================================================")

print(kontak)

print("\n\n")
# Out:
# ...
#
#                       Curriculum VITAE
#
# ...
#                                               PD.PENDI GROUP
#                                                     2021-Now
#
# Nama                  :  Andreas Jefri
# Jenis Kelamin         :  Laki-laki
# Kebangsaan            :  Indonesia
# Alamat                :  Komplek pondok indah lestari,kab.kubu raya
#
#
#
# ...
#
#                    Pendidikan Formal
#
# ...
#
# - SD 02 Nanga Arong
# - SMP Harapan Ananda
# - SMA Negeri 1 Sungai Raya
# ...
#
#                Pendidikan Non-formal
#
# ...
#
# - Bela Negara
# - Pelatihan Memasak
#
#
#
# ...
#
#                            Prestasi
#
# ...
#
# - Juara 3 Lomba Masak Sekalbar
# - Runer Up Duta Smansa
# - Juara 1 Karate
#
#
#
# ...
#
#                       Pengalaman Kerja
#
# ...
#
# - Bekerja sebagai Staf Lapangan PD.PENDI
#
#
#
#
# ...
#
#                           Organisasi
#
# ...
#
# - IPDK
# - PEMUDA BORNEO
# - PENCINTA ALAM KALBAR
# - PANGALAYO
#
#
#
#
# ...
#
#                             Kontak
#
# ...
#
# - 085821136572 (WhatsApp)
# ...

# %%
panjang = int(input("panjang:"))
lebar = int(input("lebar:"))

luas = panjang*lebar
#cetak
print("=============================================================")
print ("Luas Persegi Panjang Adalah:",luas)
print("=============================================================")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-990cd1b59984> in <module>
# ----> 1 panjang = int(input("panjang:"))
#       2 lebar = int(input("lebar:"))
#       3
#       4 luas = panjang*lebar
#       5 #cetak
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
celcius = int(input("celcius"))
reamur = celcius*0.8
fahrenheit = celcius*1.8 + 32
    #cetak
print("=============================================================")
print ("celcius:",celcius)
print ("reamur:",reamur)
print ("fahrenheit:",fahrenheit) 
print("=============================================================")
# Out:
# celcius20
# ...
# celcius: 20
# reamur: 16.0
# fahrenheit: 68.0

# %%
detik = int (input("detik"))
hari = detik/86400
temp1 =detik%86400
jam =temp1/3600
temp2=temp1%3600
menit=temp2/60
detik=temp2%60
#cetak
print("=============================================================")
print ("hari:",hari)
print ("jam:",jam)
print ("menit:",menit)
print ("detik:",detik)
print("=============================================================")
# Out:
# detik1000
# ...
# hari: 0.011574074074074073
# jam: 0.2777777777777778
# menit: 16.666666666666668
# detik: 40

# %%
jari= int (input("jari"))
luas=(22/7)*jari **2
#cetak
print("=============================================================")
print ("luas:",luas)
print("=============================================================")
# Out:
# jari7
# ...
# luas: 154.0
# ...
